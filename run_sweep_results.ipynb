# %%
import subprocess

baseline_run = "3k_baseline 2026.05.13--12-17-40"
unet_run = "3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29"
gaussian_blur_run = "3k_gaussian_blur 2026.05.26--18-42-22"
haar_wavelet_run = "3k_haar_wavelet 2026.05.26--12-12-55"

models = [
    baseline_run,
    gaussian_blur_run,
    haar_wavelet_run,
    unet_run,
]

attacks = [
    "mean",
    "telea",
    "navier",
    "shiftmap",
    "diffusion"
]

# %%
def run_sweep(run_name, attack, debug=False):
    cmd = [
        "python",
        "sweep.py",
        "-d", "images",
        "-r", "./runs",
        "--run-name", run_name,
        "--attack", attack,
        "--min-ratio", "0.1",
        "--max-ratio", "0.9",
        "--steps", "9",
        "--seed", "42",
        "-b", "1",
    ]

    if debug:
        cmd.append("--debug")

    print("Running:")
    print(" ".join(cmd))
    print()

    subprocess.run(
        cmd,
        check=True,
    )

# %%
for run_name in models:
    run_sweep(
        run_name,
        "identity",
        debug=False,
    )
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_baseline 2026.05.13--12-17-40 --attack identity --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_baseline 2026.05.13--12-17-40
# Checkpoint: ./runs/3k_baseline 2026.05.13--12-17-40/checkpoints/3k_baseline--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: identity
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# IDENTITY / CLEAN EVALUATION
# ============================================================
# Target removal ratio: 0.000000
# Actual removal ratio: 0.000000
# PSNR: 34.3935
# SSIM: 0.9473
# BER: 0.027333
#
# ============================================================
# Saved -> sweep_results/clean_M_3k_baseline_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_gaussian_blur 2026.05.26--18-42-22 --attack identity --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_gaussian_blur 2026.05.26--18-42-22
# Checkpoint: ./runs/3k_gaussian_blur 2026.05.26--18-42-22/checkpoints/3k_gaussian_blur--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: identity
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# IDENTITY / CLEAN EVALUATION
# ============================================================
# Target removal ratio: 0.000000
# Actual removal ratio: 0.000000
# PSNR: 33.2082
# SSIM: 0.9286
# BER: 0.051111
#
# ============================================================
# Saved -> sweep_results/clean_M_3k_gaussian_blur_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_haar_wavelet 2026.05.26--12-12-55 --attack identity --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_haar_wavelet 2026.05.26--12-12-55
# Checkpoint: ./runs/3k_haar_wavelet 2026.05.26--12-12-55/checkpoints/3k_haar_wavelet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: identity
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# IDENTITY / CLEAN EVALUATION
# ============================================================
# Target removal ratio: 0.000000
# Actual removal ratio: 0.000000
# PSNR: 29.8116
# SSIM: 0.9073
# BER: 0.064222
#
# ============================================================
# Saved -> sweep_results/clean_M_3k_haar_wavelet_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack identity --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: identity
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# IDENTITY / CLEAN EVALUATION
# ============================================================
# Target removal ratio: 0.000000
# Actual removal ratio: 0.000000
# PSNR: 33.4888
# SSIM: 0.9340
# BER: 0.022556
#
# ============================================================
# Saved -> sweep_results/clean_M_3k_frozen_pretrained_unet_eval_aligned_S_42.json
# ============================================================

# %%
# fixed unet-mask, make it align to eval:
for attack in attacks:
    run_sweep(
            unet_run,
            attack,
            debug=True,
        )
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack mean --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: mean
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# MEAN | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 23.9688
# SSIM: 0.8540
# BER: 0.023778
#
# ============================================================
# MEAN | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.2229
# SSIM: 0.7809
# BER: 0.024667
#
# ============================================================
# MEAN | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.4810
# SSIM: 0.7104
# BER: 0.026444
#
# ============================================================
# MEAN | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 18.1842
# SSIM: 0.6426
# BER: 0.031889
#
# ============================================================
# MEAN | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 17.1427
# SSIM: 0.5769
# BER: 0.036667
#
# ============================================================
# MEAN | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 16.2745
# SSIM: 0.5195
# BER: 0.047333
#
# ============================================================
# MEAN | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 15.5534
# SSIM: 0.4618
# BER: 0.069111
#
# ============================================================
# MEAN | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 14.7996
# SSIM: 0.4072
# BER: 0.118556
#
# ============================================================
# MEAN | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.1891
# SSIM: 0.3552
# BER: 0.252889
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_mean_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack telea --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: telea
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# TELEA | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 27.2774
# SSIM: 0.8841
# BER: 0.029000
#
# ============================================================
# TELEA | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 24.4005
# SSIM: 0.8329
# BER: 0.029667
#
# ============================================================
# TELEA | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.7288
# SSIM: 0.7833
# BER: 0.032333
#
# ============================================================
# TELEA | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 21.1255
# SSIM: 0.7285
# BER: 0.037556
#
# ============================================================
# TELEA | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.9221
# SSIM: 0.6716
# BER: 0.046222
#
# ============================================================
# TELEA | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.5638
# SSIM: 0.6117
# BER: 0.059111
#
# ============================================================
# TELEA | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.3055
# SSIM: 0.5485
# BER: 0.085778
#
# ============================================================
# TELEA | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 16.0372
# SSIM: 0.4805
# BER: 0.140889
#
# ============================================================
# TELEA | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 15.0144
# SSIM: 0.4162
# BER: 0.253444
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_telea_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack navier --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: navier
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# NAVIER | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 27.1967
# SSIM: 0.8836
# BER: 0.028889
#
# ============================================================
# NAVIER | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 24.3032
# SSIM: 0.8316
# BER: 0.028889
#
# ============================================================
# NAVIER | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.6326
# SSIM: 0.7814
# BER: 0.032444
#
# ============================================================
# NAVIER | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 21.0227
# SSIM: 0.7264
# BER: 0.034667
#
# ============================================================
# NAVIER | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.8604
# SSIM: 0.6691
# BER: 0.042667
#
# ============================================================
# NAVIER | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.5218
# SSIM: 0.6094
# BER: 0.049111
#
# ============================================================
# NAVIER | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.2912
# SSIM: 0.5462
# BER: 0.062444
#
# ============================================================
# NAVIER | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 16.0900
# SSIM: 0.4787
# BER: 0.101000
#
# ============================================================
# NAVIER | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 15.0222
# SSIM: 0.4127
# BER: 0.227111
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_navier_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack shiftmap --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: shiftmap
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# SHIFTMAP | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.2854
# SSIM: 0.8645
# BER: 0.023444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.7893
# SSIM: 0.7909
# BER: 0.024222
#
# ============================================================
# SHIFTMAP | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.4732
# SSIM: 0.7145
# BER: 0.026111
#
# ============================================================
# SHIFTMAP | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.6875
# SSIM: 0.6360
# BER: 0.028333
#
# ============================================================
# SHIFTMAP | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 16.1730
# SSIM: 0.5513
# BER: 0.031556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 14.7947
# SSIM: 0.4655
# BER: 0.037667
#
# ============================================================
# SHIFTMAP | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 13.7537
# SSIM: 0.3781
# BER: 0.043111
#
# ============================================================
# SHIFTMAP | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 12.6003
# SSIM: 0.2718
# BER: 0.064889
#
# ============================================================
# SHIFTMAP | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 10.6238
# SSIM: 0.1218
# BER: 0.231667
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_shiftmap_R_0.10_0.90_S_42.json
# ============================================================

# %%
# add diffusion attack to retangular sweep mask
for run_name in models:
    run_sweep(
        run_name,
        "diffusion",
        debug=True,
    )
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_baseline 2026.05.13--12-17-40 --attack diffusion --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_baseline 2026.05.13--12-17-40
# Checkpoint: ./runs/3k_baseline 2026.05.13--12-17-40/checkpoints/3k_baseline--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: diffusion
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# DIFFUSION | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 27.3848
# SSIM: 0.8944
# BER: 0.027333
#
# ============================================================
# DIFFUSION | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 24.3946
# SSIM: 0.8391
# BER: 0.029444
#
# ============================================================
# DIFFUSION | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.5112
# SSIM: 0.7837
# BER: 0.032889
#
# ============================================================
# DIFFUSION | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 20.8525
# SSIM: 0.7241
# BER: 0.037444
#
# ============================================================
# DIFFUSION | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.6044
# SSIM: 0.6637
# BER: 0.046333
#
# ============================================================
# DIFFUSION | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.3394
# SSIM: 0.6021
# BER: 0.074222
#
# ============================================================
# DIFFUSION | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.1790
# SSIM: 0.5367
# BER: 0.136889
#
# ============================================================
# DIFFUSION | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 15.9789
# SSIM: 0.4697
# BER: 0.241444
#
# ============================================================
# DIFFUSION | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 15.1280
# SSIM: 0.4043
# BER: 0.380111
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_baseline_A_diffusion_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_gaussian_blur 2026.05.26--18-42-22 --attack diffusion --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_gaussian_blur 2026.05.26--18-42-22
# Checkpoint: ./runs/3k_gaussian_blur 2026.05.26--18-42-22/checkpoints/3k_gaussian_blur--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: diffusion
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# DIFFUSION | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 27.1169
# SSIM: 0.8773
# BER: 0.053111
#
# ============================================================
# DIFFUSION | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 24.2642
# SSIM: 0.8238
# BER: 0.056000
#
# ============================================================
# DIFFUSION | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.4524
# SSIM: 0.7702
# BER: 0.060000
#
# ============================================================
# DIFFUSION | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 20.8065
# SSIM: 0.7124
# BER: 0.073333
#
# ============================================================
# DIFFUSION | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.5867
# SSIM: 0.6536
# BER: 0.093000
#
# ============================================================
# DIFFUSION | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.3199
# SSIM: 0.5940
# BER: 0.132222
#
# ============================================================
# DIFFUSION | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.1657
# SSIM: 0.5304
# BER: 0.195111
#
# ============================================================
# DIFFUSION | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 15.9687
# SSIM: 0.4651
# BER: 0.287778
#
# ============================================================
# DIFFUSION | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 15.1050
# SSIM: 0.4020
# BER: 0.401000
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_gaussian_blur_A_diffusion_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_haar_wavelet 2026.05.26--12-12-55 --attack diffusion --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_haar_wavelet 2026.05.26--12-12-55
# Checkpoint: ./runs/3k_haar_wavelet 2026.05.26--12-12-55/checkpoints/3k_haar_wavelet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: diffusion
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# DIFFUSION | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.8738
# SSIM: 0.8574
# BER: 0.067333
#
# ============================================================
# DIFFUSION | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 23.5140
# SSIM: 0.8051
# BER: 0.071000
#
# ============================================================
# DIFFUSION | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 21.9361
# SSIM: 0.7530
# BER: 0.075889
#
# ============================================================
# DIFFUSION | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 20.4344
# SSIM: 0.6967
# BER: 0.081222
#
# ============================================================
# DIFFUSION | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.3057
# SSIM: 0.6388
# BER: 0.092889
#
# ============================================================
# DIFFUSION | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.1045
# SSIM: 0.5802
# BER: 0.111000
#
# ============================================================
# DIFFUSION | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 16.9954
# SSIM: 0.5178
# BER: 0.133222
#
# ============================================================
# DIFFUSION | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 15.8200
# SSIM: 0.4533
# BER: 0.170444
#
# ============================================================
# DIFFUSION | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.9417
# SSIM: 0.3922
# BER: 0.237556
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_haar_wavelet_A_diffusion_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack diffusion --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: diffusion
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# DIFFUSION | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 27.1926
# SSIM: 0.8820
# BER: 0.023778
#
# ============================================================
# DIFFUSION | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 24.3033
# SSIM: 0.8277
# BER: 0.025556
#
# ============================================================
# DIFFUSION | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.4746
# SSIM: 0.7734
# BER: 0.028333
#
# ============================================================
# DIFFUSION | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 20.8244
# SSIM: 0.7150
# BER: 0.030778
#
# ============================================================
# DIFFUSION | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.5939
# SSIM: 0.6553
# BER: 0.034778
#
# ============================================================
# DIFFUSION | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.3282
# SSIM: 0.5949
# BER: 0.041000
#
# ============================================================
# DIFFUSION | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.1701
# SSIM: 0.5306
# BER: 0.050667
#
# ============================================================
# DIFFUSION | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 15.9755
# SSIM: 0.4645
# BER: 0.084667
#
# ============================================================
# DIFFUSION | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 15.1089
# SSIM: 0.4010
# BER: 0.194667
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_diffusion_R_0.10_0.90_S_42.json
# ============================================================

# %%
# keep mean fill simple
for run_name in models:
    run_sweep(
        run_name,
        "mean",
        debug=True,
    )
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_baseline 2026.05.13--12-17-40 --attack mean --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_baseline 2026.05.13--12-17-40
# Checkpoint: ./runs/3k_baseline 2026.05.13--12-17-40/checkpoints/3k_baseline--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: mean
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# MEAN | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 24.0823
# SSIM: 0.8662
# BER: 0.028556
#
# ============================================================
# MEAN | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.2829
# SSIM: 0.7922
# BER: 0.030111
#
# ============================================================
# MEAN | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.5111
# SSIM: 0.7205
# BER: 0.034889
#
# ============================================================
# MEAN | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 18.2085
# SSIM: 0.6516
# BER: 0.042889
#
# ============================================================
# MEAN | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 17.1585
# SSIM: 0.5851
# BER: 0.060000
#
# ============================================================
# MEAN | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 16.2891
# SSIM: 0.5263
# BER: 0.093333
#
# ============================================================
# MEAN | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 15.5670
# SSIM: 0.4673
# BER: 0.163889
#
# ============================================================
# MEAN | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 14.8089
# SSIM: 0.4115
# BER: 0.259222
#
# ============================================================
# MEAN | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.2071
# SSIM: 0.3576
# BER: 0.400111
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_baseline_A_mean_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_gaussian_blur 2026.05.26--18-42-22 --attack mean --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_gaussian_blur 2026.05.26--18-42-22
# Checkpoint: ./runs/3k_gaussian_blur 2026.05.26--18-42-22/checkpoints/3k_gaussian_blur--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: mean
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# MEAN | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 23.9359
# SSIM: 0.8495
# BER: 0.053556
#
# ============================================================
# MEAN | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.2021
# SSIM: 0.7775
# BER: 0.057000
#
# ============================================================
# MEAN | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.4625
# SSIM: 0.7078
# BER: 0.065889
#
# ============================================================
# MEAN | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 18.1714
# SSIM: 0.6408
# BER: 0.080556
#
# ============================================================
# MEAN | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 17.1378
# SSIM: 0.5760
# BER: 0.109889
#
# ============================================================
# MEAN | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 16.2644
# SSIM: 0.5192
# BER: 0.162667
#
# ============================================================
# MEAN | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 15.5477
# SSIM: 0.4621
# BER: 0.235667
#
# ============================================================
# MEAN | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 14.7933
# SSIM: 0.4080
# BER: 0.330333
#
# ============================================================
# MEAN | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.1865
# SSIM: 0.3562
# BER: 0.427222
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_gaussian_blur_A_mean_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_haar_wavelet 2026.05.26--12-12-55 --attack mean --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_haar_wavelet 2026.05.26--12-12-55
# Checkpoint: ./runs/3k_haar_wavelet 2026.05.26--12-12-55/checkpoints/3k_haar_wavelet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: mean
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# MEAN | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 23.2796
# SSIM: 0.8303
# BER: 0.068556
#
# ============================================================
# MEAN | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 20.8218
# SSIM: 0.7598
# BER: 0.073889
#
# ============================================================
# MEAN | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.2024
# SSIM: 0.6921
# BER: 0.082444
#
# ============================================================
# MEAN | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.9884
# SSIM: 0.6267
# BER: 0.089778
#
# ============================================================
# MEAN | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 16.9917
# SSIM: 0.5629
# BER: 0.108000
#
# ============================================================
# MEAN | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 16.1489
# SSIM: 0.5075
# BER: 0.130889
#
# ============================================================
# MEAN | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 15.4453
# SSIM: 0.4515
# BER: 0.159889
#
# ============================================================
# MEAN | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 14.6997
# SSIM: 0.3989
# BER: 0.201889
#
# ============================================================
# MEAN | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.0764
# SSIM: 0.3496
# BER: 0.284111
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_haar_wavelet_A_mean_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29 --attack mean --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29
# Checkpoint: ./runs/3k_frozen_pretrained_unet_eval_aligned 2026.08.24--04-07-29/checkpoints/3k_frozen_pretrained_unet_eval_aligned--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: mean
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# MEAN | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 23.9688
# SSIM: 0.8540
# BER: 0.023778
#
# ============================================================
# MEAN | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.2229
# SSIM: 0.7809
# BER: 0.024667
#
# ============================================================
# MEAN | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.4810
# SSIM: 0.7104
# BER: 0.026444
#
# ============================================================
# MEAN | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 18.1842
# SSIM: 0.6426
# BER: 0.031889
#
# ============================================================
# MEAN | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 17.1427
# SSIM: 0.5769
# BER: 0.036667
#
# ============================================================
# MEAN | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 16.2745
# SSIM: 0.5195
# BER: 0.047333
#
# ============================================================
# MEAN | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 15.5534
# SSIM: 0.4618
# BER: 0.069111
#
# ============================================================
# MEAN | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 14.7996
# SSIM: 0.4072
# BER: 0.118556
#
# ============================================================
# MEAN | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.1891
# SSIM: 0.3552
# BER: 0.252889
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_eval_aligned_A_mean_R_0.10_0.90_S_42.json
# ============================================================

# %% [markdown]
# # sanity check done
# run_sweep(
#     baseline_run,
#     "mean",
#     debug=True,
# )

# %% [markdown]
# # 2 nested loop, not suitable for debug
# for run_name in models:
#     for attack in attacks:
#         run_sweep(
#             run_name,
#             attack,
#             debug=True,
#         )

# %% [markdown]
# # finish unet and haar wavelet without shiftmap
# attacks_no_shiftmap = [
#     "mean",
#     "telea",
#     "navier",
# ]
# for attack in attacks_no_shiftmap:
#     run_sweep(
#         unet_run,
#         attack,
#         debug=True,
#     )

# %%
run_sweep(
    haar_wavelet_run,
    "navier",
    debug=True,
)
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_haar_wavelet 2026.05.26--12-12-55 --attack navier --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_haar_wavelet 2026.05.26--12-12-55
# Checkpoint: ./runs/3k_haar_wavelet 2026.05.26--12-12-55/checkpoints/3k_haar_wavelet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: navier
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# NAVIER | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.7770
# SSIM: 0.8578
# BER: 0.069667
#
# ============================================================
# NAVIER | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 23.4353
# SSIM: 0.8074
# BER: 0.073556
#
# ============================================================
# NAVIER | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 22.0364
# SSIM: 0.7585
# BER: 0.078222
#
# ============================================================
# NAVIER | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 20.5692
# SSIM: 0.7050
# BER: 0.087000
#
# ============================================================
# NAVIER | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 19.5076
# SSIM: 0.6491
# BER: 0.099889
#
# ============================================================
# NAVIER | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 18.2625
# SSIM: 0.5908
# BER: 0.119778
#
# ============================================================
# NAVIER | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 17.0900
# SSIM: 0.5292
# BER: 0.142000
#
# ============================================================
# NAVIER | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 15.9377
# SSIM: 0.4633
# BER: 0.182111
#
# ============================================================
# NAVIER | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 14.8634
# SSIM: 0.3965
# BER: 0.242889
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_haar_wavelet_A_navier_R_0.10_0.90_S_42.json
# ============================================================

# %%
# fix shiftmap blue color bug.
for run_name in models:
    run_sweep(
            run_name,
            "shiftmap",
            debug=True,
        )
# Out:
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_baseline 2026.05.13--12-17-40 --attack shiftmap --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_baseline 2026.05.13--12-17-40
# Checkpoint: ./runs/3k_baseline 2026.05.13--12-17-40/checkpoints/3k_baseline--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: shiftmap
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# SHIFTMAP | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.4858
# SSIM: 0.8770
# BER: 0.027444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.9520
# SSIM: 0.8023
# BER: 0.029889
#
# ============================================================
# SHIFTMAP | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.4929
# SSIM: 0.7238
# BER: 0.031889
#
# ============================================================
# SHIFTMAP | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.8180
# SSIM: 0.6461
# BER: 0.036556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 16.1930
# SSIM: 0.5579
# BER: 0.044333
#
# ============================================================
# SHIFTMAP | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 14.9122
# SSIM: 0.4727
# BER: 0.050444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 13.8091
# SSIM: 0.3837
# BER: 0.069333
#
# ============================================================
# SHIFTMAP | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 12.6098
# SSIM: 0.2749
# BER: 0.112444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 10.5817
# SSIM: 0.1246
# BER: 0.288667
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_baseline_A_shiftmap_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_gaussian_blur 2026.05.26--18-42-22 --attack shiftmap --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_gaussian_blur 2026.05.26--18-42-22
# Checkpoint: ./runs/3k_gaussian_blur 2026.05.26--18-42-22/checkpoints/3k_gaussian_blur--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: shiftmap
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# SHIFTMAP | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.2535
# SSIM: 0.8596
# BER: 0.054000
#
# ============================================================
# SHIFTMAP | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.9535
# SSIM: 0.7865
# BER: 0.056000
#
# ============================================================
# SHIFTMAP | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.5204
# SSIM: 0.7087
# BER: 0.058556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.7628
# SSIM: 0.6322
# BER: 0.065444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 16.1918
# SSIM: 0.5477
# BER: 0.072000
#
# ============================================================
# SHIFTMAP | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 14.8370
# SSIM: 0.4626
# BER: 0.084222
#
# ============================================================
# SHIFTMAP | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 13.7680
# SSIM: 0.3746
# BER: 0.097778
#
# ============================================================
# SHIFTMAP | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 12.6019
# SSIM: 0.2702
# BER: 0.138556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 10.6264
# SSIM: 0.1223
# BER: 0.310222
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_gaussian_blur_A_shiftmap_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_haar_wavelet 2026.05.26--12-12-55 --attack shiftmap --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_haar_wavelet 2026.05.26--12-12-55
# Checkpoint: ./runs/3k_haar_wavelet 2026.05.26--12-12-55/checkpoints/3k_haar_wavelet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: shiftmap
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# SHIFTMAP | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 24.2102
# SSIM: 0.8374
# BER: 0.067444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 21.2833
# SSIM: 0.7651
# BER: 0.067667
#
# ============================================================
# SHIFTMAP | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.1196
# SSIM: 0.6885
# BER: 0.069444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.4165
# SSIM: 0.6107
# BER: 0.070556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 15.9696
# SSIM: 0.5262
# BER: 0.075444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 14.6276
# SSIM: 0.4426
# BER: 0.079889
#
# ============================================================
# SHIFTMAP | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 13.6684
# SSIM: 0.3571
# BER: 0.088444
#
# ============================================================
# SHIFTMAP | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 12.4401
# SSIM: 0.2503
# BER: 0.105333
#
# ============================================================
# SHIFTMAP | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 10.5701
# SSIM: 0.1122
# BER: 0.199778
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_haar_wavelet_A_shiftmap_R_0.10_0.90_S_42.json
# ============================================================
# Running:
# python sweep.py -d images -r ./runs --run-name 3k_frozen_pretrained_unet 2026.08.22--12-55-32 --attack shiftmap --min-ratio 0.1 --max-ratio 0.9 --steps 9 --seed 42 -b 1 --debug
# /home/keen/HiDDeN/utils.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(last_checkpoint_file)
# ============================================================
# EXTERNAL ROBUSTNESS EVALUATION
# ============================================================
# Run: 3k_frozen_pretrained_unet 2026.08.22--12-55-32
# Checkpoint: ./runs/3k_frozen_pretrained_unet 2026.08.22--12-55-32/checkpoints/3k_frozen_pretrained_unet--epoch-400.pyt
# Checkpoint epoch: 400
# Attack: shiftmap
# Seed: 42
# Device: cpu
# ============================================================
# Validation images: 300
# Fixed messages generated for 300 images.
#
# ============================================================
# SHIFTMAP | removal ratio = 0.100
# ============================================================
# Target removal ratio: 0.100000
# Actual removal ratio: 0.099781
# PSNR: 25.3750
# SSIM: 0.8693
# BER: 0.018667
#
# ============================================================
# SHIFTMAP | removal ratio = 0.200
# ============================================================
# Target removal ratio: 0.200000
# Actual removal ratio: 0.199799
# PSNR: 22.0504
# SSIM: 0.7967
# BER: 0.019778
#
# ============================================================
# SHIFTMAP | removal ratio = 0.300
# ============================================================
# Target removal ratio: 0.300000
# Actual removal ratio: 0.299808
# PSNR: 19.3327
# SSIM: 0.7147
# BER: 0.020778
#
# ============================================================
# SHIFTMAP | removal ratio = 0.400
# ============================================================
# Target removal ratio: 0.400000
# Actual removal ratio: 0.399807
# PSNR: 17.6969
# SSIM: 0.6382
# BER: 0.025000
#
# ============================================================
# SHIFTMAP | removal ratio = 0.500
# ============================================================
# Target removal ratio: 0.500000
# Actual removal ratio: 0.499796
# PSNR: 16.1690
# SSIM: 0.5527
# BER: 0.028333
#
# ============================================================
# SHIFTMAP | removal ratio = 0.600
# ============================================================
# Target removal ratio: 0.600000
# Actual removal ratio: 0.599780
# PSNR: 14.8646
# SSIM: 0.4658
# BER: 0.031556
#
# ============================================================
# SHIFTMAP | removal ratio = 0.700
# ============================================================
# Target removal ratio: 0.700000
# Actual removal ratio: 0.699820
# PSNR: 13.7393
# SSIM: 0.3776
# BER: 0.040111
#
# ============================================================
# SHIFTMAP | removal ratio = 0.800
# ============================================================
# Target removal ratio: 0.800000
# Actual removal ratio: 0.799802
# PSNR: 12.6376
# SSIM: 0.2705
# BER: 0.061222
#
# ============================================================
# SHIFTMAP | removal ratio = 0.900
# ============================================================
# Target removal ratio: 0.900000
# Actual removal ratio: 0.899855
# PSNR: 10.5994
# SSIM: 0.1196
# BER: 0.221778
#
# ============================================================
# Saved -> sweep_results/sweep_M_3k_frozen_pretrained_unet_A_shiftmap_R_0.10_0.90_S_42.json
# ============================================================
